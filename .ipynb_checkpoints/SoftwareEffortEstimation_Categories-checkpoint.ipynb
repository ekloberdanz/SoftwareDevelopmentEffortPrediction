# %%
import pandas as pd
# Load Data
url = 'https://raw.githubusercontent.com/SEAnalytics/datasets/master/storypoint/IEEE%20TSE2018/dataset/mulestudio.csv'
raw_data = pd.read_csv(url)
raw_data.columns
raw_data.head(6)
# Out:
#      issuekey                                              title  \
# 0   STUDIO-95                          Support for request/reply
# 1  STUDIO-280  Cannot import a Studio project from Git withou...
# 2  STUDIO-382       Changes to Java code do not get hot deployed
# 3  STUDIO-459  Unable to add a response when creating a secon...
# 4  STUDIO-618   Namespaces in the XML view are not being remo...
# 5  STUDIO-781  Would save time to be given the option to crea...
#
#                                          description  storypoint
# 0  request/reply  http://www.mulesoft.org/documen...          13
# 1  Steps to reproduce:    1. Create a simple Mule...           3
# 2  Java source changes don't get picked up right ...           5
# 3  Unable to add a response when creating a secon...           8
# 4  When you add an element and then you remove it...           8
# 5  Add a button in the ClassFieldEditor to create...           5

# %%
# Check for missing values
raw_data.isnull().sum()
# Out:
# issuekey       0
# title          0
# description    0
# storypoint     0
# dtype: int64

# %%
# Examine storypoints summary statistics
raw_data.storypoint.describe()
# Out:
# count    732.000000
# mean       6.396175
# std        5.385687
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       34.000000
# Name: storypoint, dtype: float64

# %%
# Visualize number of storypoints distribution
import matplotlib.pyplot as plt
plt.hist(raw_data.storypoint, bins=20, alpha=0.6, color='b')
plt.title("#Items per Point")
plt.xlabel("Points")
plt.ylabel("Count")
plt.show()

# %%
# Zoom in on most common data representing 75% of the dataset
import numpy as np
frequent_data = raw_data.query('storypoint <= 8')
plt.hist(frequent_data.storypoint, bins=20, alpha=0.6, color='b')
plt.title("#Items per Point")
plt.xlabel("Points")
plt.ylabel("Count")
plt.xticks(np.arange(0, 10, 1)) 
plt.show()

# %%
# Examine distribution in detail
raw_data.groupby('storypoint').size()
# Out:
# storypoint
# 1      61
# 2      65
# 3     121
# 5     223
# 8     157
# 13     73
# 15      2
# 21     18
# 26      1
# 34     11
# dtype: int64

# %%
raw_data.loc[raw_data.storypoint <= 2, 'storypoint'] = 0 #small
raw_data.loc[(raw_data.storypoint > 2) & (raw_data.storypoint <= 5), 'storypoint'] = 1 #medium
raw_data.loc[raw_data.storypoint > 5, 'storypoint'] = 2 #big

# %%
# Examine distribution in detail
raw_data.groupby('storypoint').size()
# Out:
# storypoint
# 0    126
# 1    344
# 2    262
# dtype: int64

# %% [markdown]
# This shows that 5 the most common number of storypoints assigned to an issue/requirement.

# %%
################### Data Preprocessing ###################################

import nltk
from nltk.corpus import stopwords 
nltk.download('punkt')
nltk.download('stopwords')

# Tokenize
raw_data['tokens'] = raw_data['description'].apply(lambda x : nltk.word_tokenize(x))

type(raw_data['description'][0])
# Out:
# [nltk_data] Downloading package punkt to /home/eliska/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /home/eliska/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# str

# %%
# Convert all words to lower case
raw_data['tokens'] = raw_data['tokens'].apply(lambda x : [w.lower() for w in x])

# Remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
raw_data['tokens'] = raw_data['tokens'].apply(lambda x: [w.translate(table) for w in x])

# Remove tokens that are not alphabetic
raw_data['tokens'] = raw_data['tokens'].apply(lambda x: [w for w in x if w.isalpha()])

# Remove stop words
stop_words = stopwords.words('english')
raw_data['tokens'] = raw_data['tokens'].apply(lambda x: [w for w in x if w not in stop_words])

raw_data['tokens'] = raw_data['tokens'].apply(lambda x: nltk.Text(x))

# Lemmatization
nltk.download('wordnet')
lemmatizer = nltk.WordNetLemmatizer()
raw_data['tokens'] = raw_data['tokens'].apply(lambda x: [lemmatizer.lemmatize(w) for w in x ])

# Stemming
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
raw_data['tokens'] = raw_data['tokens'].apply(lambda x: [porter.stem(w) for w in x ])


raw_data
# Out:
# [nltk_data] Downloading package wordnet to /home/eliska/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
#         issuekey                                              title  \
# 0      STUDIO-95                          Support for request/reply
# 1     STUDIO-280  Cannot import a Studio project from Git withou...
# 2     STUDIO-382       Changes to Java code do not get hot deployed
# 3     STUDIO-459  Unable to add a response when creating a secon...
# 4     STUDIO-618   Namespaces in the XML view are not being remo...
# 5     STUDIO-781  Would save time to be given the option to crea...
# 6     STUDIO-782  View the class code just by clicking on the cl...
# 7     STUDIO-837  Reference to the subflow get lost when changin...
# 8     STUDIO-853  Studio can be a lot smarter when handling logi...
# 9    STUDIO-1212                  Response section is not displayed
# 10   STUDIO-1311  Able to drag and drop composite source and pol...
# 11   STUDIO-1333  There is no specification when there is a glob...
# 12   STUDIO-1415  Executing simple lookup table configuration is...
# 13   STUDIO-1428  Unable to create new mappings using new excel ...
# 14   STUDIO-1435    Multiple xml validation errors in Studio editor
# 15   STUDIO-1538  Undo option (command + z / Ctrl + z ) does not...
# 16   STUDIO-1676  Suggest to stop the corresponding running mule...
# 17   STUDIO-1694  Default of "Auto delete" in the File endpoint ...
# 18   STUDIO-1738                                   Add JAXB support
# 19   STUDIO-1759           More easily navigate between XML and GUI
# 20   STUDIO-1811  Studio is not validating that certain scopes s...
# 21   STUDIO-2000  Error unzipping MuleStudio in Windows in a lon...
# 22   STUDIO-2104  Unable to drag a Twitter neither a Salesforce ...
# 23   STUDIO-4050             Studio cannot be pinned to the taskbar
# 24   STUDIO-2779                    Studio Online Help Enhancements
# 25   STUDIO-2787  Fixing MES Studio behavior for fields that use...
# 26   STUDIO-2781                      Studio Support for WebSockets
# 27   STUDIO-2782  Adding Reference to CH Analytic end-point on S...
# 28   STUDIO-2784  Addition of DB2 and MS SQL Server to the list ...
# 29   STUDIO-2147  Only queryKey is marked as mandatory for JDBC ...
# ..           ...                                                ...
# 702  STUDIO-6866  [DW-UI] Usability tests to determine possible ...
# 703  STUDIO-6867                               [DW-UI] Java Support
# 704  STUDIO-6868          [DW-UI] Code Generation for special cases
# 705  STUDIO-6869       [DW-UI] Add coding support in graphical mode
# 706  STUDIO-6870   [DW-UI] Support selection in input/output trees
# 707  STUDIO-6871  [DW-UI] Get feedback from the code pane at the...
# 708  STUDIO-6872  [DW-UI] Improve how connections and context ar...
# 709  STUDIO-6873  [DW-UI] Show indicators for each field that di...
# 710  STUDIO-6874  [DW-UI] Determine how to guide the user to rep...
# 711  STUDIO-6875  [DW-UI] Add usage data collection to DataWeave...
# 712  STUDIO-6894  XSLT message processor properties does not sho...
# 713  STUDIO-6895  Create 3.7.1 Studio runtime and Studio 5.2.1 w...
# 714  STUDIO-6904  [SPIKE] Research on possible options for suppo...
# 715  STUDIO-6907       APIKit menu entry rows on none mule projects
# 716  STUDIO-6946                       [DW-UI] Add support for undo
# 717  STUDIO-6947  [DW-UI] Show a DND hint when the visual editor...
# 718  STUDIO-6948           [DW-UI] Automapping of collection fields
# 719  STUDIO-6949               [DW-UI] Add a way to remove mappings
# 720  STUDIO-6960                                Add Validator icons
# 721  STUDIO-6997  Request for improvement on the Parse Template ...
# 722  STUDIO-7006                          Dynamic mysql not working
# 723  STUDIO-7073    Add Details Panel when selecting MetaData Types
# 724  STUDIO-7075  Studio fails to open mule configurations when ...
# 725  STUDIO-7107                            Content assist slowness
# 726  STUDIO-7253  Allow to finish the new Mule project wizard wh...
# 727  STUDIO-7360   Add support for changes on connectors editor.xml
# 728  STUDIO-7386  API-GATEWAY Domain creation improvements in St...
# 729  STUDIO-7436  Allow studio to discover and instantiate Exten...
# 730  STUDIO-7479                      Create mule 4 Studio Runtimes
# 731  STUDIO-7487  Spike to verify support extension child elemen...
#
#                                            description  storypoint  \
# 0    request/reply  http://www.mulesoft.org/documen...           2
# 1    Steps to reproduce:    1. Create a simple Mule...           1
# 2    Java source changes don't get picked up right ...           1
# 3    Unable to add a response when creating a secon...           2
# 4    When you add an element and then you remove it...           2
# 5    Add a button in the ClassFieldEditor to create...           1
# 6    Currently, to view the class code (e.g., compo...           1
# 7    Steps to reproduce:   1.- Create a project in ...           2
# 8    it seems we could have a single filter element...           2
# 9    My config is as follows:  <flow name="TicketFl...           1
# 10   I am able to drag and drop composite source an...           1
# 11   This is a usability issue: There is no specifi...           2
# 12   Created a Java to XML mapping and configured a...           2
# 13   Unable to create a new mapping using an excel ...           2
# 14   1. Element JAX-WS Service is not allowed to be...           1
# 15   Steps to reproduce:   1.- Go to the global ele...           2
# 16   Steps to reproduce:  1 - Create a project  2 -...           1
# 17   To see or edit the "Auto delete" option of the...           2
# 18   It would be nice if you could support jaxb ope...           0
# 19   It should be much easier to navigate from the ...           2
# 20   (edit) This bug was first discovered for excep...           1
# 21   When unzipping MuleStudio in a long path (For ...           2
# 22   Unable to drag a Twitter neither a Salesforce ...           0
# 23   Unlike other windows programs, Studio cannot b...           2
# 24   1) Adding new content created by Antonio/Doc-t...           2
# 25      http://www.mulesoft.org/jira/browse/DEVKIT-240           2
# 26                    As defined by the specification.           2
# 27   Whenever Studio starts, we should send a GET r...           2
# 28   Today we show MySQL, Derby, and Oracle. Howeve...           2
# 29   Only queryKey is marked as mandatory for JDBC ...           0
# ..                                                 ...         ...
# 702  Criteria to determine this task as done:  - At...           2
# 703  Support 'as' operant and its format  Support e...           2
# 704  After doing drag and drop the new elements has...           2
# 705  *) The user should be able to select and edit ...           2
# 706  *) When a field is selected the assigned eleme...           2
# 707  This task is considered done if:  - We have at...           2
# 708  Improve rendering taking into account colors, ...           2
# 709  Show indicators for each field that display if...           2
# 710  This task is considered done if:  - We have mo...           1
# 711  Add the following metrics to collect data duri...           2
# 712  There are no way to add, remove or edit <mulex...           1
# 713  * Create Studio ESB Runtime 3.7.1  * Create Bi...           1
# 714  As connectors behaviour becomes more complex, ...           1
# 715  When doing a right click on a project, APIkit ...           0
# 716  This is one of the issues found during usabili...           2
# 717  This issue ocurred during the usability tests....           1
# 718  When the user maps a collection in the visual ...           1
# 719  The visual editor doesn't have a way to remove...           2
# 720      New icons for Validator module are attached.            1
# 721  Loading the template file using Mule Expressio...           0
# 722  I have a simple flow:  HttpConnector -> Flow V...           0
# 723  When selecting metadata when configuring an ht...           0
# 724  When a file has BOM markers, studio fails to l...           1
# 725  The autocomplete was recalculating the metadat...           0
# 726  When creating a new APIkit project from a Raml...           1
# 727  When a Processor has a POJO as a parameter, di...           1
# 728  When creating a Gateway project Studio automat...           1
# 729  Allow studio to discover and instantiate Exten...           2
# 730  Discuss were it will be hosted.  Verify if the...           1
# 731  Currently Studio is not prepared to support ch...           1
#
#                                                 tokens
# 0    [requestrepli, http, wwwmulesoftorgdocumentati...
# 1    [step, reproduc, creat, simpl, mule, studio, p...
# 2    [java, sourc, chang, nt, get, pick, right, aut...
# 3    [unabl, add, respons, creat, second, flow, ste...
# 4    [add, element, remov, refer, schema, file, rem...
# 5    [add, button, classfieldeditor, creat, class, ...
# 6    [current, view, class, code, eg, compon, speci...
# 7    [step, reproduc, creat, project, studio, flow,...
# 8    [seem, could, singl, filter, element, flow, co...
# 9    [config, follow, flow, name, doc, name, compos...
# 10   [abl, drag, drop, composit, sourc, poll, respo...
# 11   [usabl, issu, specif, global, endpoint, connec...
# 12   [creat, java, xml, map, configur, lookup, tabl...
# 13   [unabl, creat, new, map, use, excel, spreadshe...
# 14   [element, jaxw, servic, allow, child, element,...
# 15   [step, reproduc, go, global, element, tab, cre...
# 16   [step, reproduc, creat, project, run, mule, ap...
# 17   [see, edit, auto, delet, option, file, connect...
# 18   [would, nice, could, support, jaxb, oper, gui,...
# 19   [much, easier, navig, gui, appropri, xml, elem...
# 20   [edit, bug, first, discov, except, strategi, d...
# 21   [unzip, mulestudio, long, path, exampl, deskto...
# 22   [unabl, drag, twitter, neither, salesforc, str...
# 23   [unlik, window, program, studio, pin, taskbar,...
# 24   [ad, new, content, creat, antoniodocteam, dyna...
# 25                                              [http]
# 26                                     [defin, specif]
# 27   [whenev, studio, start, send, get, request, fo...
# 28   [today, show, mysql, derbi, oracl, howev, m, s...
# 29   [querykey, mark, mandatori, jdbc, endpoint, ad...
# ..                                                 ...
# 702  [criterion, determin, task, done, least, usabl...
# 703  [support, oper, format, support, enum, support...
# 704  [drag, drop, new, element, keep, order, defin,...
# 705  [user, abl, select, edit, script, assign, outp...
# 706  [field, select, assign, element, highlight, ou...
# 707  [task, consid, done, least, data, point, feedb...
# 708  [improv, render, take, account, color, posit, ...
# 709                 [show, indic, field, display, map]
# 710  [task, consid, done, mock, user, journey, data...
# 711  [add, follow, metric, collect, data, mvp, avg,...
# 712  [way, add, remov, edit, mulexml, contextproper...
# 713  [creat, studio, esb, runtim, creat, binari, st...
# 714  [connector, behaviour, becom, complex, develop...
# 715  [right, click, project, apikit, menu, entri, s...
# 716  [one, issu, found, usabl, test, user, creat, m...
# 717  [issu, ocur, usabl, test, user, see, visual, e...
# 718  [user, map, collect, visual, editor, ui, tri, ...
# 719              [visual, editor, nt, way, remov, map]
# 720                  [new, icon, valid, modul, attach]
# 721  [load, templat, file, use, mule, express, scen...
# 722  [simpl, flow, httpconnector, flow, variabl, db...
# 723  [select, metadata, configur, http, jiust, brow...
# 724  [file, bom, marker, studio, fail, load, mule, ...
# 725  [autocomplet, recalcul, metadata, time, execut...
# 726  [creat, new, apikit, project, raml, file, url,...
# 727  [processor, pojo, paramet, differ, option, com...
# 728  [creat, gateway, project, studio, automat, cre...
# 729  [allow, studio, discov, instanti, extensionmodel]
# 730  [discu, host, verifi, structur, distribut, cha...
# 731  [current, studio, prepar, support, child, elem...
#
# [732 rows x 5 columns]

# %%
# Vocabulary
vocabulary = set([item for sublist in list(raw_data['tokens']) for item in sublist]) # list of unique words
vocabulary_size = len(vocabulary)
vocabulary_size
# Out:
# 2750

# %%
# Frequency distribution of words
all_words = [item for sublist in list(raw_data['tokens']) for item in sublist]
len(all_words)
from nltk.probability import FreqDist
fdist = FreqDist(all_words)

# %%
list(raw_data['tokens'])[0]
# Out:
# ['requestrepli',
#  'http',
#  'wwwmulesoftorgdocumentationdisplaycurrentroutingmessageprocessor',
#  'routingmessageprocessorsrequestrepli',
#  'mockup',
#  'http',
#  'corpwikimulesourcecomdisplaywprequestrepli',
#  'requestreplymockup']

# %%
# Frequency Distribution of Words Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
# Split data into traning and testing
split_ratio = 0.7
total_number_of_datapoints = len(raw_data.index)
train_number_of_datapoints = int(total_number_of_datapoints * split_ratio)

train_set = raw_data.iloc[:train_number_of_datapoints, :]
test_set = raw_data.iloc[train_number_of_datapoints:, :]

# %%
tokens = list(train_set['tokens'])
tokens = [str(i) for i in tokens]
tokens
# Out:
# ["['requestrepli', 'http', 'wwwmulesoftorgdocumentationdisplaycurrentroutingmessageprocessor', 'routingmessageprocessorsrequestrepli', 'mockup', 'http', 'corpwikimulesourcecomdisplaywprequestrepli', 'requestreplymockup']",
#  "['step', 'reproduc', 'creat', 'simpl', 'mule', 'studio', 'project', 'instanc', 'echo', 'exampl', 'push', 'github', 'pullclon', 'repositori', 'local', 'instanc', 'open', 'brand', 'new', 'workspac', 'goto', 'importgitproject', 'git', 'select', 'local', 'copi', 'github', 'repositori', 'select', 'import', 'exist', 'project', 'select', 'project', 'creat', 'import', 'fail', 'due', 'miss', 'directori', 'see', 'screenshot', 'note', 'import', 'mule', 'project', 'work', 'nt', 'recognis', 'project', 'manag', 'git', 'commit', 'chang', 'block', 'work', 'exampl', 'edit', 'workaround', 'perform', 'clean', 'oper', 'project']",
#  "['would', 'nice', 'could', 'support', 'jaxb', 'oper', 'gui', 'jaxbxmltoobjecttransform', 'jaxbcontext', 'etc']",
#  "['much', 'easier', 'navig', 'gui', 'appropri', 'xml', 'element', 'flow', 'block', 'within', 'xml', 'furthermor', 'would', 'great', 'go', 'way', 'well', 'click', 'xml', 'element', 'bring', 'user', 'directli', 'highlight', 'flow', 'element', 'within', 'gui']",
#  "['edit', 'bug', 'first', 'discov', 'except', 'strategi', 'descript', 'case', 'use', 'messag', 'flow', 'tab', 'ca', 'nt', 'drop', 'inboundonlyendpoint', 'except', 'strategi', 'ui', 'forbid', 'abl', 'xml', 'nt', 'valid', 'indic', 'invalid', 'exampl', 'code', 'xml', 'catchexceptionstrategi', 'imap', 'inboundendpoint', 'host', 'localhost', 'port', 'responsetimeout', 'doc', 'name', 'imap', 'catchexceptionstrategi', 'code', 'invalid', 'imap', 'inbound', 'inbound', 'error', 'marker', 'whatsoev', 'present', 'underlin', 'xml', 'present', 'problem', 'problem', 'pane', 'drawn', 'redx', 'messag', 'flow', 'tab', 'also', 'valid', 'kind', 'scope', 'restrict', 'start', 'inbound', 'outbound', 'endpoint', 'sampl', 'snippet', 'fail', 'dont', 'code', 'xml', 'subflow', 'name', 'doc', 'name', 'imap', 'inboundendpoint', 'host', 'localhost', 'port', 'responsetimeout', 'doc', 'name', 'imap', 'subflow', 'code', 'code', 'xml', 'compositesourc', 'smtp', 'outboundendpoint', 'host', 'localhost', 'port', 'responsetimeout', 'doc', 'name', 'smtp', 'compositesourc', 'code', 'code', 'xml', 'poll', 'frequenc', 'imap', 'inboundendpoint', 'host', 'localhost', 'port', 'responsetimeout', 'doc', 'name', 'imap', 'poll', 'code']",
#  "['unzip', 'mulestudio', 'long', 'path', 'exampl', 'desktop', 'document', 'set', 'error', 'shown', 'attach', 'screenshot', 'may', 'shown', 'password', 'protect', 'error', 'seem', 'window', 'bug', 'explain', 'http', 'problem', 'seem', 'window', 'limit', 'much', 'chang', 'studio', 'fix', 'issu', 'fail', 'file', 'eclips', 'class', 'workaround', 'instal', 'studio', 'simpler', 'shorter', 'directori', 'exampl', 'c', 'mulestudio', 'need', 'add', 'releas', 'note', 'see', 'document', 'better', 'user', 'stuff', 'test', 'happen', 'winzip', 'winrar', 'problem', 'default', 'zip', 'util', 'come', 'window', 'extract', 'c', 'mulestudio', 'directori', 'move', 'anoth', 'locat', 'specif', 'version', 'window', 'present', 'issu']",
#  "['unabl', 'drag', 'twitter', 'neither', 'salesforc', 'stream', 'palett', 'composit', 'sourc', 'composit', 'sourc', 'contain', 'messag', 'sourc', 'therefor', 'abl', 'drag', 'drop', 'salesforc', 'twitter', 'stream', 'composit', 'sourc']",
#  "['unlik', 'window', 'program', 'studio', 'pin', 'taskbar', 'quick', 'access', 'awar', 'problem', 'eclips', 'gener', 'want', 'make', 'clear', 'usabl', 'issu', 'user', 'rightclick', 'taskbar', 'icon', 'run', 'studio', 'see', 'one', 'option', 'close', 'window']",
#  "['ad', 'new', 'content', 'creat', 'antoniodocteam', 'dynam', 'help', 'adjust', 'widget', 'id', 'make', 'sure', 'associ', 'dynam', 'help', 'content', 'display', 'dynam', 'help', 'tab', 'default', 'studio', 'upon', 'first', 'start']",
#  "['realli', 'cool', 'field', 'editor', 'data', 'sourc', 'editor', 'hit', 'tab', 'key', 'get', 'column', 'leas', 'row', 'day', 'focu', 'ok', 'button', 'move', 'mous', 'navig', 'grid']",
#  "['tri', 'insert', 'refer', 'except', 'strategi', 'insid', 'choic', 'noth', 'happen', 'messag', 'flow', 'view', 'backend', 'xml', 'view', 'except', 'strategi', 'ad', 'see', 'screenshot']",
#  "['map', 'field', 'realiz', 'ad', 'one', 'field', 'go', 'use', 'delet', 'map', 'automat', 'collaps', 'give', 'idea', 'everyth', 'delet', 'end', 'user', 'may', 'realiz', 'collapseexpand', 'issu']",
#  "['go', 'global', 'element', 'tab', 'clic', 'creat', 'write', 'jdbc', 'filter']",
#  "['set', 'xmlgener', 'compon', 'realli', 'relat', 'applic', 'xml', 'gener', 'mule', 'config', 'entiti', 'id', 'mflow', 'gener', 'long', 'random', 'string', 'step', 'reproduc', 'creat', 'projectflow', 'drop', 'imap', 'logger', 'open', 'mflow', 'text', 'editor', 'see', 'entiti', 'id', 'long', 'unrepres', 'string', 'addit', 'inform', 'upon', 'make', 'modif', 'flow', 'entityid', 'regener', 'expect', 'compnam']",
#  "['ui', 'show', 'sap', 'transform', 'warn', 'noth', 'display', 'error', 'log', 'xml', 'view', 'see', 'attach', 'screenshot', 'problem', 'relat', 'sap', 'editor', 'xml', 'definit']",
#  "['tri', 'import', 'project', 'use', 'studio', 'studio', 'coupl', 'issu', 'tri', 'gener', 'deploy', 'archetyp', 'use', 'export', 'project', 'includ', 'maven', 'depend', 'lib', 'folder', 'export', 'complain', 'folder', 'srcmainresourc', 'srctestjava', 'srctestresourc', 'exist', 'attach', 'find', 'project', 'tri', 'import', 'export']",
#  "['use', 'lookup', 'tabl', 'multipl', 'time', 'one', 'map', 'transform', 'led', 'except', 'runtim']",
#  "['hi', 'user', 'still', 'see', 'crash', 'issu', 'studio', 'even', 'appli', 'updat', 'told', 'project', 'main', 'flow', 'multipl', 'sub', 'flow', 'think', 'part', 'issu', 'may', 'mule', 'updat', 'multipl', 'flow', 'file', 'gotten', 'error', 'scenario', 'although', 'full', 'replic', 'step', 'yet', 'step', 'caus', 'time', 'flow', 'referenc', 'chang', 'name', 'origin', 'name', 'new', 'name', 'show', 'flow', 'refer', 'drop', 'tri', 'refer', 'second', 'sub', 'flow', 'first', 'sub', 'flow', 'multipl', 'sub', 'flow', 'file', 'add', 'flow', 'refer', 'call', 'get', 'error', 'note', 'move', 'issu', 'correct', 'error', 'got', 'entri', 'orgeclipseui', 'messag', 'error', 'applic', 'pleas', 'report', 'incid', 'studiofeedback', 'mulesourcecom', 'save', 'fail', 'stack', 'javalangassertionerror', 'orgmuletoolingmessagefloweditormultipagemessagefloweditor', 'mergingcontext', 'mergermerg', 'orgmuletoolingmessagefloweditormultipagemessagefloweditormergeel', 'orgmuletoolingmessagefloweditormultipagemessagefloweditorformcommand', 'orgmuletoolingmessagefloweditormultipagemessagefloweditorfixupsourc', 'or
ispatch', 'orgeclipseuiinternalworkbenchruneventloop', 'orgeclipseuiinternalworkbenchrunui', 'orgeclipseuiinternalworkbenchaccess', 'orgeclipseuiinternalworkbench', 'orgeclipsecoredatabindingobservablerealmrunwithdefault', 'orgeclipseuiinternalworkbenchcreateandrunworkbench', 'orgeclipseuiplatformuicreateandrunworkbench', 'orgeclipseuiinternalideapplicationideapplicationstart', 'orgeclipseequinoxinternalappeclipseapphandlerun', 'orgeclipsecoreruntimeinternaladaptoreclipseapplauncherrunappl', 'orgeclipsecoreruntimeinternaladaptoreclipseapplauncherstart', 'orgeclipsecoreruntimeadaptoreclipsestarterrun', 'orgeclipsecoreruntimeadaptoreclipsestarterrun', 'nativ', 'method', 'sunreflectnativemethodaccessorimplinvok', 'sunreflectdelegatingmethodaccessorimplinvok', 'javalangreflectmethodinvok', 'orgeclipseequinoxlaunchermaininvokeframework', 'orgeclipseequinoxlaunchermainbasicrun', 'orgeclipseequinoxlaunchermainrun', 'caus', 'javalangexceptionininitializererror', 'nativ', 'method', 'javalangclassfornam', 'comopensyscloveretlcomponenttreebeanschemageneratorschemageneratorh', 'unknown', 'sourc', 'comopensyscloveretlcomponenttreebeanschemageneratorschemageneratorf', 'unknown', 'sourc', 'comopensyscloveretlcomponenttreebeanschemageneratorschemageneratorb', 'unknown', 'sourc', 'comopensyscloveretlcomponenttreebeanschemageneratorschemagener', 'visitorvisit', 'unknown', 'sourc', 'comopensyscloveretlcomponenttreebeanschemamodeltypedobjectaccept ...
#  "['actual', 'bug', 'one', 'brace', 'error', 'come', 'first', 'instal', 'cloud', 'connector', 'http', 'githubcommulesoftgoogleconnectorssuitetreemastergmailconnector', 'first', 'list', 'attribut', 'get', 'label', 'descript', 'string', 'leav', 'empti', 'time', 'studio', 'regener', 'code', 'empti', 'one', 'get', 'default', 'payload', 'valu', 'ui', 'slow', 'complex', 'type', 'complex', 'defin', 'ui', 'get', 'option', 'refer', 'autocomplet', 'nt', 'work', 'either', 'complex', 'type', 'list']",
#  "['precondit', 'mule', 'studio', 'workspac', 'instal', 'ce', 'mule', 'server', 'step', 'reproduc', 'creat', 'project', 'use', 'ce', 'server', 'switch', 'project', 'runtim', 'ee', 'server', 'tri', 'use', 'eeonli', 'compon', 'busi', 'event', 'jdbc', 'ftp', 'cach', 'noth', 'happen', 'visual', 'compon', 'ad', 'except', 'log', 'error', 'log', 'see', 'code', 'javalangruntimeexcept', 'unknown', 'node', 'definit', 'http', 'wwwmulesoftorgschemamuleeetrackingcustomev', 'orgmuletoolingcoremodulemulemodulemanagergetdefinit', 'orgmuletoolingmessagefloweditpartcompartmentlaneeditpartbuildresponsemodel', 'orgmuletoolingmessagefloweditpartcompartmentlaneeditpartbuilddisplaymodel', 'orgmuletoolingmessagefloweditpartcompartmentlaneeditpartgetmodelchildren', 'orgeclipsegefeditpartsabstracteditpartrefreshchildren', 'orgmuletoolingmessagefloweditpartcompartmentlaneeditpartrefreshchildren', 'orgmuletoolingmessagefloweditpartcompartmentlaneeditpartupd', 'javautilobservablenotifyobserv
iinternalideapplicationideapplicationstart', 'orgeclipseequinoxinternalappeclipseapphandlerun', 'orgeclipsecoreruntimeinternaladaptoreclipseapplauncherrunappl', 'orgeclipsecoreruntimeinternaladaptoreclipseapplauncherstart', 'orgeclipsecoreruntimeadaptoreclipsestarterrun', 'orgeclipsecoreruntimeadaptoreclipsestarterrun', 'nativ', 'method', 'sunreflectnativemethodaccessorimplinvok', 'sunreflectdelegatingmethodaccessorimplinvok', 'javalangreflectmethodinvok', 'orgeclipseequinoxlaunchermaininvokeframework', 'orgeclipseequinoxlaunchermainbasicrun', 'orgeclipseequinoxlaunchermainrun', 'caus', 'javalangruntimeexcept', ' ...
#  "['use', 'choic', 'use', 'filter', 'insid', 'condit', 'filter', 'insid', 'processor', 'chain', 'esb', 'fail', 'deploy', 'app', 'processor', 'chain', 'alreadi', 'support', 'xml', 'need', 'add', 'palett', 'add', 'descript', 'configur', 'window']",
#  "['abl', 'drop', 'refer', 'except', 'strategi', 'insid', 'choic', 'except', 'strategi']",
#  "['use', 'connect', 'test', 'featur', 'need', 'connector', 'librari', 'automat', 'ad', 'project', 'path', 'instead', 'show', 'error', 'metadata']",
#  "['transact', 'compon', 'option', 'simpl', 'transact', 'xa', 'transact', 'multi', 'transact', 'runtim', 'use', 'ce', 'simpl', 'transact', 'option', 'display', 'icon', 'common', 'green', 'runtim', 'ee', 'option', 'display', 'icon', 'light', 'green']",
#  "['part', 'implement', 'new', 'transact', 'element', 'need', 'add', 'action', 'transact', 'endpoint', 'configur', 'transact', 'follow', 'endpoint', 'jm', 'jdbc', 'vm', 'action', 'call', 'support', 'display', 'drop', 'list', 'action', 'select', 'follow', 'attribut', 'ad', 'xml', 'action', 'notsupport']",
#  "['exampl', 'flow', 'name', 'flow', 'also', 'gener', 'doc', 'link', 'work', 'even', 'compon', 'flow', 'document', 'display', 'anywher']",
#  "['jira', 'bit', 'unusu', 'problem', 'find', 'limit', 'comment', 'make', 'studio', 'canva', 'messag', 'processor', 'name', 'doc', 'end', 'also', 'write', 'comment', 'xml', 'spread', 'comment', 'describ', 'applic', 'confus', 'believ', 'need', 'come', 'strategi', 'common', 'way', 'make', 'comment', 'could', 'potenti', 'address', 'http', 'like', 'make', 'note', 'xml', 'view', 'note', 'without', 'click', 'compon', 'hover', 'mous', 'gui', 'would', 'probabl', 'use', 'descript', 'attribut', 'give', 'detail', 'descript', 'messag', 'processor', 'would', 'like', 'sometim', 'abl', 'put', 'line', 'brief', 'descript', 'somewher', 'canva', 'doc', 'name', 'attribut', 'text', 'wrap', 'descript', 'word', 'make', 'canva', 'look', 'messi', 'forc', 'messag', 'processor', 'spread', 'good', 'way', 'label', 'sorri', 'jira']",
#  "['step', 'reproduc', 'open', 'studio', 'new', 'workspac', 'close', 'welcom', 'screen', 'clic', 'export', 'doc', 'button', 'issu', 'follow', 'npe', 'appear', 'error', 'log', 'code', 'javalangnullpointerexcept', 'orgmuletoolingstudocdialogsmuledocumentationexportdialogopen', 'orgmuletoolingstudochandlersexportstudiodocumentationhandlerexecut', 'orgeclipseuiinternalhandlershandlerproxyexecut', 'orgeclipsecorecommandscommandexecutewithcheck', 'orgeclipsecorecommandsparameterizedcommandexecutewithcheck', 'orgeclipseuiinternalhandlershandlerserviceexecutecommand', 'orgeclipseuiinternalhandlersslavehandlerserviceexecutecommand', 'orgeclipseuimenuscommandcontributionitemhandlewidgetselect', 'orgeclipseuimenuscommandcontributionitemaccess', 'orgeclipseuimenuscommandcontributionitem', 'orgeclipseswtwidgetseventtablesendev', 'orgeclipseswtwidgetsdisplaysendev', 'orgeclipseswtwidgetswidgetsendev', 'orgeclipseswtwidgetswidgetsendev', 'orgeclipseswtwidgetswidgetsendev', 'orgeclipseswtwidgetswidgetnotifylisten', 'orgeclipseswtwidgetsdisplayrundeferredev', 'orgeclipseswtwidgetsdisplayreadanddispatch', 'orgeclipseuiinternalworkbenchruneventloop', 'orgeclipseuiinternalworkbenchrunui', 'orgeclipseuiinternalworkbenchaccess', 'orgeclipseuiinternalworkbench', 'orgeclipsecoredatabindingobservablerealmrunwithdefault', 'orgeclipseuiinternalworkbenchcreateandrunworkbench', 'orgeclipseuiplatformuicreateandrunworkbench', 'orgeclipseuiinternalideapplicationideapplicationstart', 'orgeclipseequinoxinternalappeclipseapphandlerun', 'orgeclipsecoreruntimeinternaladaptoreclipseapplauncherrunappl', 'orgeclipsecoreruntimeinternaladaptoreclipseapplauncherstart', 'orgeclipsecoreruntimeadaptoreclipsestarterrun', 'orgeclipsecoreruntimeadaptoreclipsestarterrun', 'nativ', 'method', 'sunreflectnativemethodaccessorimplinvok', 'sunreflectdelegatingmethodaccessorimplinvok', 'javalangreflectmethodinvok', 'orgeclipseequinoxlaunchermaininvokeframework', 'orgeclipseequinoxlaunchermainbasicrun', 'orgeclipseequinoxlaunchermainrun', 'code']",
#  "['tri', 'use', 'studio', 'project', 'us', 'cloud', 'connector', 'depend', 'jettison', 'requir', 'classload', 'overrid', 'describ', 'page', 'http', 'edit', 'muledeployproperti', 'file', 'ad', 'loaderoverrideorgcodehausjettison', 'orgspringframeworkbatch', 'comthoughtworksxstream', 'ignor', 'current', 'deploy', 'built', 'app', 'use', 'maven', 'deploy', 'manual', 'mule', 'mule', 'deploy', 'pay', 'attent', 'flag', 'applic', 'deploy', 'fine', 'need', 'support', 'studio', 'asap', 'forc', 'tell', 'client', 'stop', 'use']",
#  "['recrecr', 'creat', 'global', 'endpoint', 'ie', 'file', 'endpoint', 'dedic', 'flow', 'file', 'store', 'global', 'compon', 'refer', 'global', 'endpoint', 'across', 'separ', 'flow', 'file', 'complet', 'flow', 'test', 'make', 'sure', 'work', 'use', 'graphic', 'editor', 'messag', 'flow', 'tab', 'edit', 'display', 'name', 'node', 'point', 'refer', 'remov', 'flow', 'broken', 'explan', 'tri', 'introduc', 'test', 'driven', 'develop', 'use', 'functionaltest', 'need', 'put', 'endpoint', 'togeth', 'connector', 'separ', 'dedic', 'flow', 'file', 'srctestresourc', 'creat', 'test', 'flow', 'file', 'contain', 'correspond', 'endpoint', 'name', 'replac', 'real', 'endpoint', 'function', 'test
#  "['default', 'task', 'tag', 'enabl', 'gener', 'editor', 'structur', 'test', 'editor', 'task', 'tag', 'activ', 'default', 'would', 'provid', 'task', 'tag', 'support', 'xml', 'configur', 'file']",
#  "['even', 'though', 'match', 'tag', 'enabl', 'gener', 'editor', 'text', 'editor', 'annot', 'match', 'tag', 'ex', 'flow', 'posit', 'flow', 'nt', 'get', 'highlight']",
#  "['take', 'project', 'go', 'build', 'path', 'option', 'make', 'whatev', 'modif', 'ad', 'item', 'classpath', 'click', 'ok', 'classpath', 'file', 'rewriten', 'mflow', 'delet', 'filesystem', 'actual', 'see', 'delet', 'oper', 'go', 'git', 'statu', 'verifi', 'studio']",
#  "['right', 'default', 'add', 'tag', 'setvari', 'flowref', 'doc', 'name', 'attribut', 'default', 'thing', 'like', 'variabl', 'flow', 'refer', 'unless', 'user', 'provid', 'someth', 'specif', 'default', 'someth', 'repres', 'processor', 'exampl', 'case', 'case', 'flowref', 'name', 'flow', 'referenc', 'case', 'setvari', 'setproperti', 'could', 'someth', 'like', 'name', 'express', 'case', 'foreach', 'could', 'collect', 'express', 'forth', 'work', 'creat', 'processor', 'use', 'visual', 'view', 'also', 'code', 'like', 'champ', 'xml', 'view']",
#  "['studio', 'complain', 'databas', 'connector', 'databas', 'sourc', 'name', 'need', 'uniqu', 'one', 'connector', 'uniqu', 'may', 'happen', 'endpoint', 'seen', 'databas', 'element']",
#  "['step', 'reproduc', 'download', 'attach', 'project', 'import', 'studio', 'edit', 'build', 'path', 'mule', 'project', 'add', 'testdepend', 'project', 'requir', 'project', 'run', 'flow', 'trigger', 'except', 'caus', 'javalangclassnotfoundexcept', 'commulesoftsupportsarasa', 'usecas', 'work', 'studio']",
#  "['tri', 'run', 'test', 'maven', 'use', 'studio', 'gener', 'pom', 'file', 'run', 'follow', 'issu', 'invalid', 'content', 'found', 'start', 'element', 'datamapp', 'config', 'add', 'depend', 'groupid', 'commulesoftmuleesbmodul', 'groupid', 'artifactid', 'mulemoduledatamapp', 'artifactid', 'version', 'mulevers', 'version', 'scope', 'provid', 'scope', 'depend', 'run', 'error', 'creat', 'bean', 'name', 'inner', 'bean', 'invoc', 'init', 'method', 'fail', 'nest', 'except', 'javalangnoclassdeffounderror', 'orgmulemodulerebooteemulecontainerbootstrap', 'orgmuleapilifecycleinitialisationexcept']",
#  "['studio', 'user', 'would', 'like', 'abl', 'use', 'object', 'builder', 'static', 'metadata']",
#  "['debug', 'mule', 'flow', 'ctrlshifti', 'open', 'mule', 'evalu', 'window', 'allow', 'test', 'mule', 'express', 'fine', 'howev', 'debug', 'java', 'transform', 'shortcut', 'open', 'java', 'evalu', 'window', 'regular', 'eclips', 'happen', 'mule', 'debugg', 'inspect', 'tool', 'open', 'instead', 'studio', 'intercept', 'debugg', 'relat', 'shortcut', 'rout', 'javamul', 'debugg', 'accordingli', 'depend', 'context']",
#  "['edit', 'flow', 'ref', 'select', 'box', 'list', 'avail', 'flow', 'alpha', 'sort', 'filter', 'textbox', 'would', 'also', 'extrem', 'help']",
#  "['endpoint', 'exchang', 'pattern', 'set', 'oneway', 'ad', 'new', 'endpoint', 'exist', 'flow', 'chang', 'properti', 'scope', 'endpoint', 'messag', 'processor', 'reproduc', 'creat', 'new', 'flow', 'add', 'endpoint', 'default', 'oneway', 'vm', 'jm', 'set', 'endpoint', 'exchang', 'pattern', 'requestrespons', 'close', 'project', 'reopen', 'project', 'xml', 'file', 'add', 'endpoint', 'one', 'mention', 'step', 'save', 'endpoint', 'mention', 'step', 'exchangepattern', 'chang', 'oneway']",
#  "['step', 'reproduc', 'goto', 'file', 'new', 'select', 'mule', 'project', 'click', 'next', 'type', 'name', 'field', 'ajax', 'spell', 'checker', 'click', 'next', 'new', 'mule', 'flow', 'dialog', 'file', 'name', 'field', 'set', 'project', 'name', 'nt', 'replac', 'whitespac', 'underscor']",
#  "['get', 'follow', 'error', 'consol', 'tri', 'run', 'test', 'case', 'us', 'ee', 'xatransact', 'ee', 'multitransact', 'error', 'commulesourcelicmimpltruelicensehelp', 'could', 'nt', 'valid', 'licens', 'key']",
# ...
#  "['updat', 'mvel', 'branch', 'latest', 'mvel', 'chang']",
#  "['design', 'web', 'servic', 'icon', 'palett', 'canva']",
#  "['creat', 'updat', 'editor']",
#  "['creat', 'delet', 'editor']",
#  "['must', 'abl', 'discov', 'wsdl', 'filesystem', 'consum', 'find', 'servic', 'metadata']",
#  "['must', 'abl', 'type', 'url', 'wsdl', 'consum', 'find', 'servic', 'metadata']",
#  "['add', 'metadata', 'support', 'insert']",
#  "['add', 'metadata', 'support', 'updat']",
#  "['add', 'metadata', 'support', 'delet']",
#  "['enabl', 'datasens', 'normal', 'datasens', 'propag']",
#  "['old', 'databas', 'renam', 'jdbc', 'deprec']",
#  "['add', 'support', 'transact']",
#  "['creat', 'palett', 'canva', 'icon', 'new', 'databas', 'element']",
#  "['defin', 'palett', 'locat', 'new', 'databas', 'element']",
#  "['need', 'iter', 'exist', 'categorytyp', 'filter', 'capabl', 'implement', 'framework', 'batch', 'contain', 'current', 'contain', 'declar', 'categorytyp', 'accept', 'accept', 'support', 'one', 'logic', 'oper', 'per', 'sentenc', 'sens', 'cardin', 'need', 'also', 'cover', 'lot', 'compon', 'scope', 'composit', 'sourc', 'poll', 'etc', 'current', 'achiev', 'lot', 'custom', 'way', 'lot', 'custom', 'attribut', 'like', 'acceptsonlyon', 'hasmultiplechildren', 'allowsonlyinbound', 'etc', 'lead', 'absolut', 'chao', 'aim', 'build', 'express', 'languag', 'build', 'filter', 'similar', 'regex', 'languag', 'allow', 'use', 'logic', 'oper', 'use', 'nest', 'sentenc', 'parenthesi', 'declar', 'cardin', 'handl', 'type', 'categori']",
#  "['user', 'choos', 'gener', 'default', 'datamapp', 'feedback', 'provid', 'default', 'gener', 'complet', 'see', 'mockup', 'guidanc', 'notic', 'mockup', 'repres', 'phase', 'improv', 'http', 'corpwikimulesourcecomdisplaywpmiscellan', 'miscellaneousdm']",
#  "['complex', 'flow', 'mp', 'like', 'choic', 'scope', 'clutter', 'interfac', 'much', 'studio', 'give', 'option', 'collaps', 'item', 'readabl']",
#  "['studio', 'debugg', 'autogener', 'mel', 'queri', 'select', 'element', 'debugg', 'view']",
#  "['work', 'choic', 'router', 'current', 'cumbersom', 'realli', 'know', 'branch', 'condit', 'end', 'go', 'xml', 'view', 'everi', 'time', 'would', 'nice', 'could', 'hover', 'top', 'branch', 'studio', 'would', 'show', 'condit', 'appli', 'condit', 'branch', 'addit', 'would', 'even', 'better', 'click', 'condit', 'studio', 'would', 'let', 'edit', 'express']",
#  "['sometim', 'especi', 'maintain', 'applic', 'need', 'track', 'applic', 'logic', 'howev', 'flowref', 'hard', 'track', 'referenc', 'flow', 'come', 'back', 'call', 'flow', 'thu', 'would', 'nice', 'could', 'see', 'preview', 'referenc', 'flow', 'hover', 'top', 'flowref', 'messag', 'processor']",
#  "['work', 'complex', 'configur', 'file', 'usual', 'need', 'go', 'back', 'forth', 'graphic', 'xml', 'view', 'would', 'much', 'effici', 'switch', 'xml', 'view', 'studio', 'would', 'automat', 'focu', 'xml', 'section', 'relat', 'graphic', 'activ', 'element']",
#  "['metadata', 'web', 'servic', 'consum', 'gener', 'repres', 'entir', 'messag', 'oper', 'propag', 'first', 'part', 'messag']",
#  "['attempt', 'connect', 'wsdl', 'connect', 'take', 'long', 'way', 'cancel', 'oper', 'studio', 'respond', 'step', 'add', 'web', 'servic', 'consum', 'canva', 'enter', 'follow', 'url', 'wsdl', 'field', 'url', 'wsdl', 'slow', 'connect', 'http', 'wsfcdynecomweatherwsweatherasmx', 'wsdl']",
#  "['oauth', 'modul', 'merg', 'mule', 'ee', 'start', 'dolomit', 'version', 'user', 'want', 'studio', 'support', 'configur', 'oauth', 'appear', 'option', 'palett', 'ootb', 'user', 'updat', 'oauth', 'modul', 'updat', 'site', 'addsremov', 'modul', 'mule', 'applic', 'ui', 'consist', 'function', 'offer', 'modul', 'rrinaudo', 'dandiep', 'fyi', 'studio', 'side']",
#  "['switch', 'view', 'common', 'shortcut', 'would', 'realli', 'improv', 'experi']",
#  "['detail', 'http', 'docsgooglecomamulesoftcomspreadsheetccc', 'uspdriveweb']",
#  "['renam', 'soap', 'cxf', 'palett']",
#  "['user', 'want', 'abl', 'datamap', 'even', 'null', 'payload', 'map', 'input', 'argument', 'output', 'creat', 'web', 'servic', 'queri', 'eg', 'someon', 'poll', 'web', 'servic', 'use', 'watermark', 'creat', 'queri']",
#  "['need', 'appli', 'esb', 'xml', 'chang', 'current', 'editor', 'pend', 'add', 'spec']",
#  "['add', 'support', 'syntax', 'highlight', 'make', 'editor', 'look', 'similar', 'one', 'sfdc', 'queri', 'add', 'autocomplet', 'mel', 'express', 'make', 'look', 'better', 'gener']",
#  "['add', 'support', 'connect', 'pool']",
#  "['order', 'make', 'xmlmetadatamodel', 'display', 'metadata', 'outlin', 'object', 'common', 'need', 'self', 'descript', 'order', 'logic', 'around', 'schema', 'introspect', 'need', 'implement']",
#  "['support', 'type', 'group', 'connector', 'datasens', 'integr', 'devkit']",
#  "['add', 'palett', 'search', 'keyword', 'new', 'databas', 'connector', 'make', 'appear', 'suggest', 'search', 'sql', 'databas', 'mysql', 'select', 'insert', 'etc']",
#  "['use', 'xsd', 'file', 'attach', 'issu', 'select', 'root', 'element', 'txlife', 'creat', 'map', 'take', 'long', 'studio', 'run', 'memori', 'code', 'javalangoutofmemoryerror', 'java', 'heap', 'space', 'suntextucompactintarrayinitplan', 'suntextucompactintarraysetelementat', 'javatextrbtablebuilderaddord', 'javatextrbtablebuilderbuild', 'javatextrbcollationt', 'init', 'javatextrulebasedcol', 'init', 'javatextcollatorgetinst', 'javatextcollatorgetinst', 'comcloveretlcommonsbeanlistpropertysupport', 'init', 'comcloveretlcommonsbeanlistpropertysupport', 'init', 'comcloveretlguimodelgraphmetadata', 'init', 'comcloveretlguimodelgraphmetadata', 'init', 'comcloveretlguimodelgraphmetadata', 'init', 'comcloveretlguimodelbuilderetlgraphbuildera', 'comcloveretlguimodelbuilderetlgraphbuildera', 'comcloveretlguimodelbuilderetlgraphbuilderbuild', 'comcloveretlguimodelbuilderetlgraphbuilderbuild', 'comcloveretlguimodelbuilderetlgraphbuilderbuildgraphmodel', 'commulesoftmuledatamapperuieditordatamappereditor', 'opengraphjobrun', 'orgeclipsecoreinternaljobsworkerrun', 'code']",
#  "['spring', 'allow', 'multipl', 'properti', 'placehold', 'need', 'use', 'attribut', 'ignoreunresolv', 'get', 'error', 'placehold', 'variabl', 'found', 'code', 'test', 'connect', 'fail', 'invalid', 'bean', 'definit', 'name', 'mysqlproperti', 'defin', 'null', 'could', 'resolv', 'placehold', 'mysqlpassword', 'string', 'valu', 'mysqlpassword', 'orgmuleapilifecycleinitialisationexcept', 'orgmulecommonmuleartifactfactoryexcept', 'error', 'initi', 'orgmuleconfigspringspringxmlconfigurationmuleartifactfactorydogetartifact', 'code', 'spring', 'wo', 'nt', 'look', 'anoth', 'placehold', 'definit', 'unless', 'attribut', 'ignoreunresolv', 'set', 'proper', 'configur', 'propertyplacehold', 'look', 'like', 'code', 'context', 'propertyplacehold', 'locat', 'oracleproperti', 'ignoreunresolv', 'true', 'code', 'studio', 'add', 'warn', 'config', 'file', 'indic', 'multipl', 'properi', 'placehold', 'ignoreunresolv', 'set', 'true']",
#  "['choic', 'support', 'autocomplet', 'express']",
#  "['build', 'condit', 'datasens', 'queri', 'support', 'autocomplet', 'filter', 'valu', 'dsqlnativ', 'queri', 'languag', 'text', 'box']",
#  "['use', 'datasens', 'leak', 'prevent', 'need', 'happen', 'around', 'jdbc', 'thread', 'timer', 'mbean', 'etc', 'ensur', 'datasens', 'classload', 'garbag', 'collect']",
#  "['friendli', 'name', 'long', 'descript', 'get', 'ad', 'metadata', 'model', 'field', 'datamapp', 'payload', 'explor', 'use', 'repres', 'payload', 'need', 'mockup']",
#  "['move', 'new', 'db', 'connector', 'back', 'ce', 'studio']",
#  "['edit', 'field', 'mule', 'properti', 'view', 'order', 'save', 'chang', 'made', 'need', 'focu', 'view', 'studio', 'allow', 'save', 'file', 'ideal', 'behaviour', 'would', 'allow', 'save', 'chang', 'immedi', 'chang', 'field', 'without', 'lose', 'focu']",
#  "['chang', 'inner', 'db', 'oper', 'child', 'element', 'xxxsql', 'xxxqueri', 'templatesql', 'templatequeryref', 'accord', 'new', 'xsd', 'chang']",
#  "['need', 'finish', 'implement', 'http', 'docsgooglecomamulesoftcomspreadsheetccc', 'uspdriveweb']",
#  "['need', 'propog', 'record', 'variabl', 'inform', 'across', 'batch', 'step']",
#  "['support', 'creat', 'aggreg', 'strategi', 'global', 'element', 'http', 'corpwikimulesourcecomdisplaywpmiscellan', 'miscellaneousscattergath', 'avail', 'global', 'element', 'creat', 'tab', 'aggreg', 'strategi', 'show', 'listchoos', 'scattergath', 'createedit', 'strategi', 'directli', 'scattergath']",
#  "['need', 'support', 'record', 'variabl', 'insid', 'debugg']",
#  "['watermark', 'function', 'requir', 'own', 'flow', 'synchron', 'process', 'strategi', 'fine', 'howev', 'synchron', 'flow', 'default', 'mean', 'put', 'watermark', 'flow', 'start', 'applic', 'get', 'deploy', 'except', 'say', 'flow', 'synchron', 'confus', 'user', 'requir', 'read', 'log', 'find', 'messag', 'chang', 'flow', 'tri', 'would', 'great', 'upon', 'enabl', 'watermark', 'studio', 'could', 'automat', 'set', 'flow', 'process', 'strategi', 'synchron']",
#  "['improv', 'studio', 'analyt', 'kissmetr', 'report', 'includ', 'studio', 'version', 'o', 'report', 'url', 'includ', 'version', 'studiovers', 'fullvers', 'fullstudiovers', 'o', 'runningo', 'javavers', 'javavers']",
#  "['look', 'find', 'object', 'salesforc', 'expect', 'combo', 'box', 'searchabl', 'start', 'type', 'quickli', 'find', 'look']",
#  "['gener', 'tab', 'clear', 'applic', 'data', 'run', 'junit', 'complic', 'run', 'kind', 'test', 'particular', 'function', 'test', 'case', 'run', 'applic', 'reli', 'o', 'pleas', 'check', 'attach', 'document']",
#  "['need', 'improv', 'ux', 'agre', 'fairli', 'confus', 'tbd', 'exactli']",
#  "['user', 'want', 'abl', 'drag', 'item', 'datasens', 'explor', 'text', 'box', 'express', 'gener', 'accept', 'criterion', 'must', 'work', 'payload', 'variabl', 'properti', 'must', 'use', 'syntax', 'must', 'properli', 'escap', 'properti', 'ie', 'foo', 'bar', 'baz', 'must', 'support', 'map', 'pojo', 'must', 'handl', 'thing', 'correctli', 'drag', 'exist', 'express', 'v', 'empti', 'text', 'box', 'must', 'support', 'xml', 'todo', 'valid', 'way']",
#  "['user', 'abl', 'configur', 'whether', 'want', 'show', 'deprec', 'messag', 'processor', 'accept', 'criterion', 'messag', 'processor', 'deprec', 'must', 'hiddenshown', 'accord', 'prefer', 'project', 'messag', 'processor', 'deprec', 'must', 'still', 'shown', 'behavior', 'xml', 'autocomplet', 'new', 'instal', 'check', 'default']",
#  "['need', 'document', 'chang', 'add', 'releas', 'note']",
#  "['user', 'attempt', 'drag', 'endpoint', 'end', 'start', 'flow', 'studio', 'allow', 'action', 'throw', 'warn', 'set', 'overwritten', 'mockup', 'http', 'corpwikimulesourcecomdisplaywpgeneralimprov', 'generalimprovementsmoveendpointtofrontofflow']",
#  "['user', 'add', 'new', 'messag', 'processor', 'flow', 'focu', 'jump', 'new', 'mp', 'inform', 'appear', 'mule', 'properti', 'view']",
#  "['user', 'attempt', 'highlight', 'copi', 'text', 'disabl', 'field', 'current', 'imposs', 'recent', 'exampl', 'mysql', 'databas', 'config', 'ref']",
#  "['problem', 'whole', 'datasens', 'stori', 'though', 'user', 'start', 'ad', 'endpoint', 'oper', 'canva', 'configur', 'global', 'config', 'element', 'creat', 'connector', 'configur', 'first', 'user', 'end', 'deadlock', 'step', 'reproduc', 'start', 'new', 'projectconfigur', 'file', 'go', 'global', 'element', 'tab', 'creat', 'new', 'salesforc', 'configur', 'configur', 'proper', 'connect', 'paramet', 'hit', 'test', 'connect', 'ok', 'salesforc', 'librari', 'still', 'ad', 'project', 'datasens', 'run', 'requir', 'sfdc', 'jar', 'part', 'classpath', 'yet', 'way', 'move', 'forward', 'disabl', 'datasens', 'support', 'hit', 'ok', 'ok', 'done', 'sfdc', 'librari', 'ad', 'project', 'open', 'global', 'element', 'editor', 'enabl', 'datasens', 'execut', 'test', 'connect', 'click', 'ok', 'retriev', 'd', 'type']",
#  "['studio', 'qa', 'great', 'real', 'world', 'web', 'servic', 'schema', 'get', 'qa', 'plan', 'test', 'keep', 'mind', 'confidenti', 'dand']",
#  "['fhir', 'schema', 'brought', 'qa', 'http']",
#  "['need', 'updat', 'dm', 'mel', 'function', 'receiv', 'null', 'also', 'return', 'null']",
#  "['option', 'nt', 'retriev', 'metadata', 'disabl', 'edit', 'connector', 'configur', 'retri']",
#  "['store', 'metadata', 'reus', 'across', 'messag', 'processor', 'whenev', 'possibl', 'user', 'nt', 'constantli', 'get', 'bombard', 'popup']",
#  "['need', 'add', 'support', 'show', 'record', 'var', 'explor', 'record', 'var', 'shown', 'time']",
#  "['implement', 'studio', 'work', 'see', 'spec', 'http', 'corpwikimulesourcecomdisplaywpmuleclusterperformanceprofil']",
#  "['upgrad', 'sap', 'connector', 'mule', 'latest', 'releas', 'one']",
#  "['cancel', 'retriv', 'datasens', 'type', 'oper', 'press', 'cancel', 'dialog', 'trigger', 'new', 'retriev', 'time']",
#  "['filter', 'element', 'palett', 'ad', 'filter', 'let', 'say', 'salesf', 'compon', 'filter', 'properli', 'enter', 'keyword', 'hit', 'complet', 'text', 'disappear', 'eras', 'complet', 'filter', 'hit', 'enter', 'nt', 'anyth', 'search', 'alreadi', 'done', 'enter', 'word', 'salesf', 'would', 'nice', 'remov', 'action', 'era', 'input']",
#  "['deprecationdisappear', 'compon', 'suggest', 'scatter', 'gather', 'palett', 'user', 'search']"]

# %% [markdown]
# Count Vectorization (One-Hot-Encoding)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# Create our vectorizer
vectorizer = CountVectorizer()
vectors = vectorizer.fit_transform(list(train_set['description']))

# Build the classifier
clf = MultinomialNB(alpha=.01)

#  Train the classifier
clf.fit(vectors, train_set['storypoint'].values)

# Get the test vectors
vectors_test = vectorizer.transform(list(test_set['description']))

# Predict and score the vectors
pred = clf.predict(vectors_test)
acc_score = metrics.accuracy_score( test_set['storypoint'].values, pred)
f1_score = metrics.f1_score( test_set['storypoint'].values, pred, average='macro')

print('Total accuracy classification score: {}'.format(acc_score))
print('Total F1 classification score: {}'.format(f1_score))
# Out:
# Total accuracy classification score: 0.44545454545454544
# Total F1 classification score: 0.3628068628068628
